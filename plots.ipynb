# %%
import torch
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pruning_experiment_results_SYNTHETIC.csv')
df_flat = df.melt(id_vars=['condition', 'p'], 
                  value_vars=["test_clean", "test_naive", "test_robust"],
                  var_name='Model', value_name='Accuracy')
sns.lineplot(data=df_flat, x='p', y='Accuracy', hue='condition', style='Model')
# Out:
# <Axes: xlabel='p', ylabel='Accuracy'>

# %%
sns.lineplot(data=df, x='p', y='test_clean')
sns.lineplot(data=df, x='p', y='test_clean')

# %%
df_flat = df.melt(id_vars=['condition', 'p'], 
                  value_vars=["train_clean", "train_naive", "train_robust"],
                  var_name='Model', value_name='Accuracy')
sns.lineplot(data=df_flat, x='p', y='Accuracy', hue='condition', style='Model')
# Out:
# <Axes: xlabel='p', ylabel='Accuracy'>

# %%
df = pd.read_csv('pruning_experiment_results_CORA.csv')
df_train = df.melt(id_vars=['condition', 'p'],
                    value_vars=["train_clean", "train_naive", "train_robust"],
                    var_name='Model', value_name='Accuracy')
sns.lineplot(data=df_train, x='p', y='Accuracy', hue='condition', style='Model')
# Out:
# <Axes: xlabel='p', ylabel='Accuracy'>

# %%
df_test = df.melt(id_vars=['condition', 'p'],
                    value_vars=["test_clean", "test_naive", "test_robust"],
                    var_name='Model', value_name='Accuracy')
sns.lineplot(data=df_test, x='p', y='Accuracy', hue='condition', style='Model')
# Out:
# <Axes: xlabel='p', ylabel='Accuracy'>

# %%
df = pd.read_csv('pruning_experiment_results_CITESEER.csv')
df_train = df.melt(id_vars=['condition', 'p'],
                    value_vars=["train_clean", "train_naive", "train_robust"],
                    var_name='Model', value_name='Accuracy')
sns.lineplot(data=df_train, x='p', y='Accuracy', hue='condition', style='Model')
# Out:
# <Axes: xlabel='p', ylabel='Accuracy'>

# %%
df_test = df.melt(id_vars=['condition', 'p'],
                    value_vars=["test_clean", "test_naive", "test_robust"],
                    var_name='Model', value_name='Accuracy')
sns.lineplot(data=df_test, x='p', y='Accuracy', hue='condition', style='Model')
# Out:
# <Axes: xlabel='p', ylabel='Accuracy'>
